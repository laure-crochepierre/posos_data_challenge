# %%
import pandas as pd 
import numpy as np
import itertools

# %% [markdown]
# ## Procedure utilisée pour créer une ligne assez exhaustive de médicaments

# %% [markdown]
# Fichiers issus de https://www.data.gouv.fr/fr/datasets/evaluation-des-medicaments/#_

# %%
df_medicaments_1 = pd.read_csv('DATA/ASMR_20171123.csv', encoding = "ISO-8859-1", sep=';')
df_medicaments_1["nom"] = [x.split()[0][1:].lower() for x in df_medic["$Dénomination spécialité$"] ]

# %%
columns = ['Code CIS',"Denomination","Forme pharmaceutique","voies d'administration","Status",
           "Type de procédure d'autorisation de mise sur le marché (AMM)","Etat de commercialisation",
           "Date d’AMM","StatutBdm","Numéro de l’autorisation européenne","Titulaire(s)","Surveillance renforcée", "Unkown"]
df_medicaments_2 = pd.read_table("DATA/CIS_bdpm.txt", encoding = "ISO-8859-1", sep='\t', names = columns).drop(0).drop(1)

# %% [markdown]
# Liste des médicaments remboursés par l'assurance maladie
# https://www.data.gouv.fr/fr/datasets/medicaments-rembourses-par-lassurance-maladie/#_

# %%
df_medicaments_3 = pd.read_csv('DATA/liste_medicaments_rembourses.csv', sep=';')
df_medicaments_3.columns
# Out:
# Index(['NOM COURT'], dtype='object')

# %% [markdown]
# Liste des médicaments dopants https://www.data.gouv.fr/fr/datasets/liste-des-medicaments-et-des-substances-dopantes/#_

# %%
df_medicaments_4 = pd.read_csv('DATA/medicaments_dopants.csv', sep=';')
df_medicaments_4.columns
# Out:
# Index(['DenomSpe'], dtype='object')

# %% [markdown]
# Medicaments non remboursables
# https://www.data.gouv.fr/fr/datasets/etude-sur-l-evolution-du-prix-des-produits-d-automedication-non-remboursables-en-france/#_

# %%
#df_medicaments_5 = pd.read_csv('DATA/medicaments_non_remboursables.csv', sep=';')
#df_medicaments_5.columns

# %%
medicaments = []
medics_to_process_1 = list(df_medicaments_1["nom"].unique())
medics_to_process_2 = [x.split()[0].lower() for x in df_medicaments_2["Denomination"] ]
medics_to_process_3 = [x.split()[0].lower() for x in df_medicaments_3['NOM COURT'] ]
medics_to_process_4 = [x.split()[0].lower() for x in df_medicaments_4['DenomSpe'] ]
medics_to_process = [medics_to_process_1, medics_to_process_2, medics_to_process_3, medics_to_process_4]

for medics_list in medics_to_process:
    for m in medics_list:
        m_splited = m.split('/')
        for i in range(len(m_splited)):
            if not m_splited in medicaments:
                medicaments.append(m_splited[i])
# Out:
# ['revestive',
#  'daptomycine',
#  'aciclovir',
#  'dopaceptin',
#  'cinqaero',
#  'ezetimibe',
#  'dafalgan',
#  'furosemide',
#  'levetiracetam',
#  'colistimethate',
#  'caspofungine',
#  'xenetix',
#  'actynox',
#  'atosiban',
#  'oxycodone',
#  'docetaxel',
#  'actonel',
#  'brilique',
#  'srivasso',
#  'fluorocholine',
#  'irinotecan',
#  'niquitin',
#  'betaserc',
#  'hydrocortisone',
#  'pergoveris,',
#  'levonorgestrel',
#  'ethinylestradiol',
#  'lomexin',
#  'truxima',
#  'ucedane',
#  'vaxigriptetra,',
#  'povidone',
#  'selexid',
#  'desogestrel',
#  'amikacine',
#  'imipenem',
#  'cilastatine',
#  'bosentan',
#  'ibuprofene',
#  'pneumovax,',
#  'bortezomib',
#  'palmier',
#  'omnipaque',
#  'erythromycine',
#  'talmanco',
#  'bendamustine',
#  'benepali',
#  'ganciclovir',
#  'chlorure',
#  'nicotine',
#  'trolovol',
#  'tivicay',
#  'pemetrexed',
#  'rolufta',
#  'ilaris',
#  'varuby',
#  'rixathon',
#  'erelzi',
#  'hexvix',
#  'glycerol',
#  'vaseline',
#  'paraffine',
#  'epirubicine',
#  'fraxiparine',
#  'xeljanz',
#  'acetate',
#  'nandiktor',
#  'xarelto',
#  'uptravi',
#  'keytruda',
#  'benefix',
#  'ledaga',
#  'paracetamol',
#  'monoprost',
#  'cefazoline',
#  'linezolide',
#  'granpidam',
#  'zinplava',
#  'dotarem',
#  'olumiant',
#  'trisenox',
#  'junimin,',
#  'isopedia,',
#  'aerivio',
#  'novorapid',
#  'betadine',
#  'dalacine',
#  'isosorbide',
#  'emend',
#  'blincyto',
#  'levothyrox',
#  'somakit',
#  'gemcitabine',
#  'zawek',
#  'fiasp',
#  'enstilar',
#  'milrinone',
#  'descovy',
#  'iceca',
#  'xalkori',
#  'afstyla',
#  'tracleer',
#  'tektrotyd',
#  'esomeprazole',
#  'codoliprane',
#  'leptoprol',
#  'laventair',
#  'revinty',
#  'domperidone',
#  'paroxetine',
#  'trinordiol,',
#  'tagrisso',
#  'imbruvica',
#  'ninlaro',
#  'dulcilarmes',
#  'octagam',
#  'intuniv',
#  'zydelig',
#  'kanuma',
#  'cytarabine',
#  'propofol',
#  'aprokam',
#  'ocaliva',
#  'sandostatine',
#  'venclyxto',
#  'beclometasone',
#  'zinforo',
#  'rekovelle',
#  'praluent',
#  'albumine',
#  'voriconazole',
#  'parsabiv',
#  'opdivo',
#  'clindamycine',
#  'synagis',
#  'relistor',
#  'heparine',
#  'ibrance',
#  'gardasil',
#  'prostatep',
#  'nasonex',
#  'pantoprazole',
#  'mikicort',
#  'oxaliplatine',
#  'alfalastin',
#  'rovalcyte',
#  'stelara',
#  'zytiga',
#  'translarna',
#  'iasotoc',
#  'atacand',
#  'cetinor',
#  'onivyde',
#  'cimzia',
#  'radiogardase',
#  'potassium',
#  'zolpidem',
#  'yervoy',
#  'revlimid',
#  'fertifol',
#  'cabometyx',
#  'nordimet',
#  'pecfent',
#  'cortiment',
#  'sulfate',
#  'morphine',
#  'bromhydrate',
#  'diazepam',
#  'ezetrol',
#  'flolan,',
#  'adcetris',
#  'glucose',
#  'mysildecard',
#  'rabipur,',
#  'modopar',
#  'truvada',
#  'magnesium',
#  'secnol',
#  'norcholesterol',
#  'novatrex',
#  'halaven',
#  'xydalba',
#  'dermoval',
#  'xeomin',
#  'panzyga',
#  'zavedos',
#  'tetravac-acellulaire,',
#  'orfadin',
#  'afinitor',
#  'peridys',
#  'oroperidys',
#  'buspirone',
#  'humira',
#  'entresto',
#  'monover',
#  'myozyme',
#  'zinbryta',
#  'odefsey',
#  'temesta',
#  'zavicefta',
#  'kinox',
#  'obizur',
#  'aminophylline',
#  'bepanthen',
#  'iblias',
#  'bricanyl',
#  'nplate',
#  'emerade',
#  'exjade',
#  'iasocholine',
#  'taltz',
#  'pixuvri',
#  'gazyvaro',
#  'spregal,',
#  'aldurazyme',
#  'lixiana',
#  'symbicort',
#  'vasculocis',
#  'revolade',
#  'extencilline',
#  'hospasol167',
#  'hospasol145',
#  'clinimix',
#  'palonosetron',
#  'zepatier',
#  'epclusa',
#  'dexpanthenol',
#  'metvixia',
#  'trevicta',
#  'numetah',
#  'bactrim,',
#  'penthrox',
#  'acarizax',
#  'haldol',
#  'cyramza',
#  'inexium',
#  'lonsurf',
#  'alprolix',
#  'procysbi',
#  'kovaltry',
#  'rozex',
#  'cosimprel,',
#  'cosimprel',
#  'travatan',
#  'flixabi',
#  'galafold',
#  'adrenaline',
#  'idelvion',
#  'lactinette',
#  'ionsys',
#  'tegeline',
#  'colchicine',
#  'colchimax,',
#  'esmya',
#  'eylea',
#  'cefotaxime',
#  'neofordex',
#  'octaplex',
#  'vasten',
#  'inofer,',
#  'holoclar,',
#  'armisarte',
#  'oxygene',
#  'gluconate',
#  'fycompa',
#  'eau',
#  'jardiance',
#  'briviact',
#  'phosphoneuros,',
#  'polaramine',
#  'kenzen',
#  'abasaglar',
#  'vitamine',
#  'levemir',
#  'mirena',
#  'skudexum',
#  'iasoglio',
#  'repaglinide',
#  'nulojix',
#  'gadovist',
#  'velcade',
#  'xalatan',
#  'daivonex',
#  'volibris',
#  'likozam',
#  'iclusig',
#  'biphozyl,',
#  'octaplaslg,',
#  'tygacil',
#  'dolipraneliquiz',
#  'mydrane',
#  'metoject',
#  'cisatracurium',
#  'oncaspar',
#  'spiolto',
#  'roferon-a',
#  'caelyx',
#  'noxafil',
#  'victan',
#  'cholib',
#  'copaxone',
#  'busilvex',
#  'avastin',
#  'herceptin',
#  'giotrif',
#  'alimta',
#  'levact',
#  'voncento',
#  'mono',
#  'anoro',
#  'fludesoxyglucose-(18f)',
#  'befizal',
#  'eptifibatide',
#  'tramadol',
#  'paracetamol',
#  'jakavi',
#  'trimebutine',
#  'roactemra',
#  'champix',
#  'mianserine',
#  'metyrapone',
#  'cosentyx',
#  'tardyferon',
#  'wakix',
#  'baraclude',
#  'vfend',
#  'adenosine',
#  'omeprazole',
#  'kogenate',
#  'innovair',
#  'formodual',
#  'simponi',
#  'cotellic',
#  'orkambi',
#  'distilbene',
#  'praxbind',
#  'fluorochol',
#  'ultibro',
#  'miglustat',
#  'nucala',
#  'nefopam',
#  'dopaview',
#  'olanzapine',
#  'flumazenil',
#  'spinafol',
#  'zimino',
#  'strensiq',
#  'kalydeco',
#  'esmocard',
#  'kyprolis',
#  'norvir',
#  'ciprofloxacine',
#  'daklinza',
#  'zerbaxa',
#  'cresemba',
#  'regiocit,',
#  'aloxi',
#  'kengrexal',
#  'akynzeo',
#  'soludactone',
#  'clamoxyl',
#  'elocta',
#  'dacarbazine',
#  'odomzo',
#  'finasteride',
#  'genvoya',
#  'alprazolam',
#  'yondelis',
#  'respreeza',
#  'mannitol',
#  'tadenan',
#  'incruse',
#  'sustiva',
#  'somatuline',
#  'noradrenaline',
#  'simvastatine',
#  'octanate',
#  'zalviso',
#  'ursolvan',
#  'kuvan',
#  'trasylol',
#  'multihance',
#  'salmeson',
#  'formoterol',
#  'deltyba',
#  'xelevia',
#  'farydak',
#  'increlex',
#  'xofigo',
#  'mekinist',
#  'somavert',
#  'cyclophosphamide',
#  'mitoxantrone',
#  'chlorhydrate',
#  'nivolumab',
#  'mopral',
#  'zoltum',
#  'berinert',
#  'seebri',
#  'amoxicilline',
#  'nicopass',
#  'ticovac',
#  'airflusal',
#  'ovaleap',
#  'janumet',
#  'repatha',
#  'prezista',
#  'jetrea',
#  'menotrophine',
#  'otezla',
#  'mestinon',
#  'orencia',
#  'resitune',
#  'zyclara',
#  'variquel',
#  'ascabiol',
#  'temozolomide',
#  'ondansetron',
#  'jinarc',
#  'orbactiv',
#  'velmetia',
#  'januvia',
#  'decapeptyl',
#  'lenvima',
#  'vectibix',
#  'moventig',
#  'suppliven,',
#  'abilify',
#  'targinact',
#  'opsumit',
#  'eporatio',
#  'adoport',
#  'nutryelt,',
#  'ameluz',
#  'natulan',
#  'imeth',
#  'bcg-medac,',
#  'prohance',
#  'droperidol',
#  'isentress',
#  'eurobiol',
#  'zykadia',
#  'rixubis',
#  'toujeo',
#  'raplixa,',
#  'xultophy',
#  'teglutik',
#  'lansoprazole',
#  'keppra',
#  'stivarga',
#  'menjugate',
#  'femara',
#  'rocuronium',
#  'targaxan',
#  'levobupivacaine',
#  'amiped,',
#  'duoplavin',
#  'erwinase',
#  'sivextro',
#  'lemtrada',
#  'deticene',
#  'xadago',
#  'niquitinminis',
#  'ikervis',
#  'jext',
#  'timoferol',
#  'retacrit',
#  'tobramycine',
#  'ascofer',
#  'lipiodol',
#  'hexyon,',
#  'diosmectite',
#  'tisseel,',
#  'hyqvia',
#  'lercapress',
#  'ceftriaxone',
#  'pediaven',
#  'remsima',
#  'zanextra',
#  'tixtar',
#  'aminoplasmal',
#  'daivobet',
#  'busulfan',
#  'forxiga',
#  'steovess',
#  'xigduo',
#  'enbrel',
#  'izalgi',
#  'evarrest,',
#  'accofil',
#  'structocal',
#  'xgeva',
#  'eligard',
#  'cerdelga',
#  'phenylephrine',
#  'atovaquone',
#  'proguanil',
#  'topalgic',
#  'tachosil,',
#  'fluarixtetra,',
#  'lucentis',
#  'dualkopt',
#  'spiriva',
#  'monoxyde',
#  'nexavar',
#  'ofev',
#  'pravastatine',
#  'contramal',
#  'ozurdex',
#  'tacrolimus',
#  'nuwiq',
#  'victoza',
#  'rotop-nanohsa',
#  'negaban',
#  'fluarix,',
#  'microval,',
#  'fenofibrate',
#  'ventavis',
#  'metformine',
#  'galantamine',
#  'cromoglicate',
#  'setofilm',
#  'ketoconazole',
#  'liptruzet',
#  'erbitux',
#  'trulicity',
#  'lynparza',
#  'plegridy',
#  'eprex',
#  'atropine',
#  'mycohydralin',
#  'cloxacilline',
#  'metronidazole',
#  'exviera',
#  'viekirax',
#  'levidcen',
#  'benzathine',
#  'signifor',
#  'ephedrine',
#  'duoresp',
#  'humalog',
#  'valdoxan',
#  'ketosteril,',
#  'beagyne',
#  'levofloxacine',
#  'elaprase',
#  'ribavox',
#  'xtandi',
#  'octreotide',
#  'gavisconpro',
#  'moxifloxacine',
#  'advate',
#  'harvoni',
#  'clareal',
#  'lojuxta',
#  'litak',
#  'velphoro',
#  'arzerra',
#  'envarsus',
#  'desopop',
#  'fluenz',
#  'bydureon',
#  'mabthera',
#  'eliquis',
#  'brintellix',
#  'tectasim',
#  'triumeq',
#  'neosynephrine',
#  'sylvant',
#  'mozobil',
#  'inomax',
#  'esbriet',
#  'cometriq',
#  'wilfactin',
#  'vancomycine',
#  'simbrinza',
#  'creon',
#  'methotrexate',
#  'ganfort',
#  'firmagon',
#  'cisplatine',
#  'votubia',
#  'ketoprofene',
#  'bemfola',
#  'striverdi',
#  'latuda',
#  'zopiclone',
#  'desloratadine',
#  'bromazepam',
#  'tercian',
#  'xolair',
#  'izba',
#  'izinova,',
#  'efient',
#  'fampyra',
#  'gammanorm',
#  'lasilix',
#  'eucreas',
#  'relvar',
#  'entyvio',
#  'botox',
#  'icandra',
#  'jalra',
#  'galvus',
#  'crestor',
#  'vokanamet',
#  'proleukin',
#  'zonegran',
#  'vimizim',
#  'inflectra',
#  'para-aminosalicylic',
#  'nicotinell',
#  'grastofil',
#  'paclitaxel',
#  'topiscab',
#  'fer',
#  'nicorette',
#  'suboxone',
#  'oxomemazine',
#  'curosurf',
#  'olysio',
#  'toctino',
#  'javlor',
#  'myleugyne',
#  'stribild',
#  'optimizette',
#  'ferinject',
#  'ultravist',
#  'abraxane',
#  'sirturo',
#  'fosfocine',
#  'tyverb',
#  'hemangiol',
#  'adempas',
#  'trombovar',
#  'palexia',
#  'naf',
#  'mesna',
#  'onezyp',
#  'normosang',
#  'metastron,',
#  'beromun',
#  'naglazyme',
#  'muphoran,',
#  'baritekal',
#  'tomudex',
#  'nipent',
#  'photofrin',
#  'vipdomet',
#  'vipidia',
#  'kineret',
#  'ethyol',
#  'leustatine',
#  'daunoxome',
#  'noxap',
#  'venlafaxine',
#  'quadramet',
#  'brilivo',
#  'natrixam',
#  'cabergoline',
#  'sativex,',
#  'ecobec',
#  'invokana',
#  'bexsero',
#  'vitaros',
#  'duphalac',
#  'lidocaine',
#  'iomeron',
#  'colobreathe',
#  'insuman',
#  'tirofiban',
#  'veletri',
#  'zostavax,',
#  'carmyne',
#  'eviplera',
#  'omniscan',
#  'inspra',
#  'fluocyne',
#  'kadcyla',
#  'novoeight',
#  'lantus',
#  'influvac',
#  'remifentanil',
#  'ixiaro,',
#  'qutenza',
#  'adasuve',
#  'plenadren',
#  'recivit',
#  'yttriga,',
#  'tetmodis',
#  'thiocolchicoside',
#  'mabelio',
#  'inlyta',
#  'physioneal',
#  'oxytocine',
#  'sovaldi',
#  'meronem',
#  'defitelio',
#  'epipen',
#  'eurartesim',
#  'leponex',
#  'lidocaine',
#  'prilocaine',
#  'extraneal,',
#  'trobalt',
#  'pheburane',
#  'orphacol',
#  'dymista',
#  'omnitrope',
#  'dextromethorphane',
#  'tarka',
#  'cefuroxime',
#  'benlysta',
#  'alevetabs',
#  'cerubidine',
#  'tadim',
#  'effilevo',
#  'effilevocontinu',
#  'nicotinamide',
#  'proglicem',
#  'incivo',
#  'betmiga',
#  'innohep',
#  'glivec',
#  'prevenar',
#  'tafinlar',
#  'clarityne',
#  'meropenem',
#  'imipenem',
#  'piperacilline',
#  'pomalidomide',
#  'chloraprep,',
#  'zoloft',
#  'pegasys',
#  'optaflu,',
#  'erivedge',
#  'confidex',
#  'privigen',
#  'plasmalyte',
#  'fostimonkit',
#  'jaydess',
#  'delprim',
#  'hexabrix',
#  'fluconazole',
#  'inductos',
#  'factane',
#  'riamet',
#  'victrelis',
#  'aubagio',
#  'acide',
#  'remicade',
#  'rapiscan',
#  'antarene',
#  'wystamm',
#  'nutropinaq',
#  'tecfidera',
#  'menopur',
#  'cayston',
#  'xaluprine',
#  'misoone',
#  'succicaptal',
#  'depakine',
#  'gelaspan,',
#  'tensionorme,',
#  'aspirine',
#  'bosulif',
#  'loxapac',
#  'miffee',
#  'selincro',
#  'zocor',
#  'antigone',
#  'carboplatine',
#  'picato',
#  'cleviprex',
#  'hizentra',
#  'influvac,',
#  'viread',
#  'byetta',
#  'neostigmine',
#  'cyrdanax',
#  'intelence',
#  'perjeta',
#  'komboglyze',
#  'onglyza',
#  'zaltrap',
#  'steozol',
#  'lumigan',
#  'extavia',
#  'tresiba',
#  'melaxose',
#  'nicorettespray',
#  'neupro',
#  'somatostatine',
#  'certican',
#  'ketamine',
#  'iluvien',
#  'proinuline',
#  'ciloxadex',
#  'ditropan',
#  'vesicare',
#  'hydraperf,',
#  'phocytan',
#  'topotecan',
#  'stablon',
#  'ceris',
#  'toviaz',
#  'novoseven',
#  'smofkabiven,',
#  'refacto',
#  'rebif',
#  'fosrenol',
#  'intralipide',
#  'clorotekal',
#  'arixtra',
#  'trajenta',
#  'carbaglu',
#  'quinimax',
#  'menveo,',
#  'effala',
#  'nevanac',
#  'betagan',
#  'melaxose,',
#  'infanrix',
#  'huvanof',
#  'mifegyne',
#  'vimpat',
#  'optidril',
#  'dacogen',
#  'flutiform',
#  'iffeza',
#  'affera',
#  'visipaque',
#  'stalevo',
#  'tahor',
#  'nimenrix,',
#  'monoox',
#  'urapidil',
#  'entonox',
#  'dafalganhop',
#  'avaxim',
#  'jentadueto',
#  'topotecane',
#  'chirocaïne',
#  'votrient',
#  'helicidine',
#  'klipal',
#  'cromofree',
#  'modixis',
#  'immunoglobuline',
#  'droleptan',
#  'dysport',
#  'dolstic',
#  'dexdor',
#  'mirtazapine',
#  'bronchitol,',
#  'alcool',
#  'cefoxitine',
#  'fluenz,',
#  'doxorubicine',
#  'eludrilperio',
#  'inovelon',
#  'ropivacaine',
#  'zyvoxid',
#  'protoxyde',
#  'monoketo',
#  'jevtana',
#  'soliris',
#  'diltiazem',
#  'polyionique',
#  'aranesp',
#  'smofkabiven',
#  'clarelux',
#  'revatio',
#  'dificlir',
#  'pylera',
#  'transulose1,75',
#  'spifen',
#  'betesil',
#  'zeclar',
#  'breakyl',
#  'optilova',
#  'ametycine',
#  'mycoster',
#  'viraferonpeg',
#  'tranxene',
#  'rasilez',
#  'alvesco',
#  'medikinet',
#  'adriblastine',
#  'actilyse,',
#  'zelboraf',
#  'baclofene',
#  'globulines',
#  'caprelsa',
#  'procoralan',
#  'norcuron',
#  'buccolam',
#  'fluorouracile',
#  'tamiflu',
#  'anapen',
#  'cinryze',
#  'tarceva',
#  'lamaline',
#  'aldactone',
#  'edurant',
#  'exforge',
#  'ydralbum',
#  'osvaren',
#  'fluticasone',
#  'tysabri',
#  'viramune',
#  'vyndaqel',
#  'cholurso',
#  'biseptinescrub,',
#  'delursan',
#  'targretin',
#  'kiovig',
#  'zometa',
#  'cetraxal',
#  'iasoflu',
#  'folinate',
#  'kamiapen',
#  'lhrh',
#  'potactasol',
#  'tasigna',
#  'tepadina',
#  'antasol',
#  'fluoxetine',
#  'lyrica',
#  'ritaline',
#  'ofloxacine',
#  'gestodene',
#  'ethinylestradiol',
#  'asmanex',
#  'oxycontin',
#  'oxynorm',
#  'oxynormoro',
#  'oralair',
#  'soluprick',
#  'oravir',
#  'nicardipine',
#  'cozaar',
#  'vinorelbine',
#  'pradaxa',
#  'neutravera',
#  'seresta',
#  'sevoflurane',
#  'tobi',
#  'epiduo,',
#  'cacit',
#  'biocadextro',
#  'ovitrelle',
#  'spasfon',
#  'protelos',
#  'cefepime',
#  'vantas',
#  'phloroglucinol',
#  'trimethylphloroglucinol',
#  'instanyl',
#  'yellox',
#  'sifrol',
#  'arganova',
#  'xeroquel',
#  'sycrest',
#  'xeplion',
#  'avonex',
#  'meteospasmyl,',
#  'idarubicine',
#  'pristam',
#  'flexbumin',
#  'genotonorm',
#  'voltarene',
#  'prolia',
#  'gonadotrophine',
#  'moviprep,',
#  'zutectra',
#  'apokinon',
#  'saizen',
#  'ciloxan',
#  'flebogamma',
#  'sumatriptan',
#  'eludrilpro,',
#  'gardasil,',
#  'eosine',
#  'aricept',
#  'tussidane',
#  'tanganil',
#  'arcoxia',
#  'octegra',
#  'bilaska',
#  'ebixa',
#  'reminyl',
#  'inorial',
#  'alfuzosine',
#  'exelon',
#  'celebrex',
#  'reanutriflex',
#  'siklos',
#  'mednutriflex',
#  'topiramate',
#  ...]

# %%
# exporte liste de medicaments en fichier txt
f = open('DATA/medicaments.txt', 'w')
for item in medicaments:
    f.write("%s\n" % item)

# %%
'mercilon' in medicaments
# Out:
# False

# %%
len(medicaments)
# Out:
# 34901
